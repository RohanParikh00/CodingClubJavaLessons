# %%
#def startHang():
#    print("______________________")
#    print("|          ||           ")
#    print("|          ||           ")
#    for i in range(0,15):
#        print("|")   
#^^unneeded?
#hard version of hangman function
compStr = ""
numWrong = 0
listCorrect = []
listIncorrect = []
tolerance = 0
def easyHang():
    
#word that is being played
    global compStr
    global numWrong
    print("______________________")
    print("|          ||           ")
    if(numWrong == 0):
        print("|")
        for i in range(0,14):
                print("|")
    if(numWrong == 1):
        print("|       |‾‾‾‾‾‾|       ")
        for i in range(0,2):
            print("|       |      |       ")
            i += 1
        print("|       |______|       ")
        if(numWrong == 1):
            for i in range(0,10):
                print("|")
    if(numWrong == 2):
        print("|       |‾‾‾‾‾‾|       ")
        print("|       | 0    |       ")
        print("|       |      |       ")
        print("|       |______|       ")
        if(numWrong == 2):
            for i in range(0,10):
                print("|")
    if(numWrong == 3):
        print("|       |‾‾‾‾‾‾|       ")
        print("|       | 0  0 |       ")
        print("|       |      |       ")
        print("|       |______|       ")
        if(numWrong == 3):
            for i in range(0,10):
                print("|")
    if(numWrong >= 4):
        print("|       |‾‾‾‾‾‾|       ")
        print("|       | 0  0 |       ")
        print("|       |  ㄥ  |       ")
        print("|       |_≤--≥_|       ")
        if(numWrong == 4):
            for i in range(0,10):
                print("|")
    if(numWrong == 5):
        for i in range(0,2):
            print("|          ||")
            i += 1
        print("|          ||")
        for i in range(0,2):
            print("|          ||")
            i += 1
        for i in range(0,5):
            print("|")
    if(numWrong == 6):
        for i in range(0,2):
            print("|          ||")
            i += 1
        print("|  ========||")
        for i in range(0,2):
            print("|          ||")
            i += 1
        if(numWrong == 6):
            for i in range(0,5):
                print("|")
    if(numWrong >= 7):
        for i in range(0,2):
            print("|          ||")
            i += 1
        print("|  ========||========")
        for i in range(0,2):
            print("|          ||")
            i += 1
        if(numWrong == 7):
            for i in range(0,5):
                print("|")
    if(numWrong == 8):
        print("|         //")
        print("|        // ")
        print("|       //  ")
        print("|      //   ")
        print("|     //    ")
        print("")
    if(numWrong >= 9):
        print("|         //\\\\")
        print("|        //  \\\\")
        print("|       //    \\\\")
        print("|      //      \\\\")
        print("|     //        \\\\")
        print("")
    print("")
def medHang(): 
    #word that is being played
    global compStr
    global numWrong
    print("______________________")
    print("|          ||           ")
    if(numWrong == 0):
        print("|")
        for i in range(0,14):
                print("|")
    if(numWrong >= 1):
        print("|       |‾‾‾‾‾‾|       ")
        for i in range(0,2):
            print("|       |      |       ")
            i += 1
        print("|       |______|       ")
        if(numWrong == 1):
            for i in range(0,10):
                print("|")
    if(numWrong == 2):
        for i in range(0,2):
            print("|          ||")
            i += 1
        print("|          ||")
        for i in range(0,2):
            print("|          ||")
            i += 1
        for i in range(0,5):
            print("|")
    if(numWrong == 3):
        for i in range(0,2):
            print("|          ||")
            i += 1
        print("|  ========||")
        for i in range(0,2):
            print("|          ||")
            i += 1
        if(numWrong == 3):
            for i in range(0,5):
                print("|")
    if(numWrong >= 4):
        for i in range(0,2):
            print("|          ||")
            i += 1
        print("|  ========||========")
        for i in range(0,2):
            print("|          ||")
            i += 1
        if(numWrong == 3):
            for i in range(0,5):
                print("|")
    if(numWrong == 5):
        print("|         //")
        print("|        // ")
        print("|       //  ")
        print("|      //   ")
        print("|     //    ")
        print("")
    if(numWrong >= 6):
        print("|         //\\\\")
        print("|        //  \\\\")
        print("|       //    \\\\")
        print("|      //      \\\\")
        print("|     //        \\\\")
        print("")
    print("")

def hardHang():
    #word that is being played
    global compStr
    global numWrong
    print("______________________")
    print("|          ||           ")
    if(numWrong == 0):
        print("|")
        for i in range(0,14):
                print("|")
    if(numWrong >= 1):
        print("|       |‾‾‾‾‾‾|       ")
        for i in range(0,2):
            print("|       |      |       ")
            i += 1
        print("|       |______|       ")
        if(numWrong == 1):
            for i in range(0,10):
                print("|")
    if(numWrong == 2):
        for i in range(0,2):
            print("|          ||")
            i += 1
        print("|          ||")
        for i in range(0,2):
            print("|          ||")
            i += 1
        for i in range(0,5):
            print("|")
    if(numWrong >= 3):
        for i in range(0,2):
            print("|          ||")
            i += 1
        print("|  ========||========")
        for i in range(0,2):
            print("|          ||")
            i += 1
        if(numWrong == 3):
            for i in range(0,5):
                print("|")
    if(numWrong >= 4):
        print("|         //\\\\")
        print("|        //  \\\\")
        print("|       //    \\\\")
        print("|      //      \\\\")
        print("|     //        \\\\")
        print("")
    print("")
    
def printWord():
    for i in range(0,len(compStr)):
        if(listCorrect.count(compStr[i]) > 0):
            print(" " + compStr[i] + " ", end = "")
        else:
            print("__ ", end = "")
        i += 1
      
                
#compare guess to word in hangman, return index if it is right, else return -1
def compareGuess():
    for i in range(0,len(compStr)):
        if(compStr[i] == letterInput):
            return i
        else:
            i += 1
    return -1

def numInstancesOfGuess() :
    k = 0
    for i in range(0,len(compStr)):
        if(letterInput == compStr[i]):
            k += 1
        else: 
            k = k
        i += 1
    return k
def levelDiff():
    global tolerance
    if(diffLevel == "easy"):
        easyHang()
        tolerance = 9
    elif(diffLevel == "medium"):
        medHang()
        tolerance = 6
    elif(diffLevel == "hard"):
        hardHang()
        tolerance = 4
    else:
        levelDiff()
#ask if user is playing 1 player or 2 player
numPlayers = input("Type 1 for single player or 2 for 2-player: ")
diffLevel = input("What level of difficulty do you want to play (easy, medium, or hard)")
diffLevel = diffLevel.lower()
if(numPlayers == "1"):
    compStr = "hansa"
    levelDiff()
    printWord()
    #user picks a letter
    while((len(listCorrect) != len(compStr)) and (len(listIncorrect) < tolerance)):
        letterInput = input("Guess a letter: ")
        letterInput = letterInput.lower()
        #check if letter matches any of string, return index or -1, and run hardhang with correct function
        if(compareGuess() >= 0):
            levelDiff()           
            for i in range(0, numInstancesOfGuess()):
                listCorrect.append(letterInput)
            printWord()
            print("")
            print("Nice, you got a letter right!")
        else:
            numWrong += 1
            levelDiff()
            printWord()
            print("")
            print("Wrong!")
            listIncorrect.append(letterInput)
    if(len(listCorrect) == len(compStr)):
        print("Great job, you win!")
    else:
        print("Sorry, you lose!")
elif(numPlayers == "2"):
    compStr = input("Player 1, input the word: ")
    levelDiff()
    printWord()
    #user picks a letter
    while((len(listCorrect) != len(compStr)) and (len(listIncorrect) < tolerance)):
        letterInput = input("Player 2, guess a letter: ")
        letterInput = letterInput.lower()
        #check if letter matches any of string, return index or -1, and run hardhang with correct function
        if(compareGuess() >= 0):
            levelDiff()
            for i in range(0, numInstancesOfGuess()):
                listCorrect.append(letterInput)
            printWord()
            print("")
            print("Nice, you got a letter right!")
        else:
            numWrong += 1
            levelDiff()
            printWord()
            print("")
            print("Wrong!")
            listIncorrect.append(letterInput)
    if(len(listCorrect) == len(compStr)):
        print("Player 2 wins!")
    else:
        print("Player 1 wins!")
# Out:
# Type 1 for single player or 2 for 2-player: 1
# What level of difficulty do you want to play (easy, medium, or hard)easy
# ______________________
# |          ||
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
#
# __ __ __ __ __ Guess a letter: w
# ______________________
# |          ||
# |       |‾‾‾‾‾‾|
# |       |      |
# |       |      |
# |       |______|
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
#
# __ __ __ __ __
# Wrong!
# Guess a letter: e
# ______________________
# |          ||
# |       |‾‾‾‾‾‾|
# |       | 0    |
# |       |      |
# |       |______|
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
#
# __ __ __ __ __
# Wrong!
# Guess a letter: r
# ______________________
# |          ||
# |       |‾‾‾‾‾‾|
# |       | 0  0 |
# |       |      |
# |       |______|
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
#
# __ __ __ __ __
# Wrong!
# Guess a letter: t
# ______________________
# |          ||
# |       |‾‾‾‾‾‾|
# |       | 0  0 |
# |       |  ㄥ  |
# |       |_≤--≥_|
# |
# |
# ...
